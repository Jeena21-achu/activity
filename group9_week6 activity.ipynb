# %%
# reading dataset to python
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df=pd.read_excel("C:\\Users\\DELL\\Desktop\\ICT REF\\group activity\\6\\Dataset_w6.xlsx")

# %%
df.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia              652864
# 1              Albania  SouthernEurope               28748
# 2              Algeria  NorthernAfrica             2381741
# 3               Angola    MiddleAfrica             1246700
# 4  Antigua and Barbuda       Caribbean                 442
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530                         623.2
# 1                            2930                        3984.2
# 2                           41318                        4154.1
# 3                           29784                        4714.1
# 4                             102                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                             125                                        3568
# ...

# %% [markdown]
# # 1. Find out how many countries are there in the dataset.

# %%
df['country'].count()
# Out:
# 196

# %% [markdown]
# # 2. Examine the data by using visualizations.

# %%
#heatmap
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %% [markdown]
# # 3. Find out how many countries with respect to the region are available in the dataset

# %%
countries=df.groupby('Region')['country'].count()
countries
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %% [markdown]
# # 4. On average which region has the highest

# %% [markdown]
# # a. GDP per capita (current US$)

# %%
region=df.groupby('Region')['GDP per capita (current US$)'].mean().nlargest(1)
region
# Out:
# Region
# NorthernAmerica    57659.0
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# # b. International trade: Imports (million US$)

# %%
region=df.groupby('Region')['International trade: Imports (million US$)'].mean().nlargest(1)
region
# Out:
# Region
# NorthernAmerica    663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
region=df.groupby('Region')['GDP per capita (current US$)'].var().nsmallest(1)
region
# Out:
# Region
# WesternAfrica    664380.509714
# Name: GDP per capita (current US$), dtype: float64
